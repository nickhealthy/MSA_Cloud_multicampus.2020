# %% [markdown]
# ### Cine21 영화배우 정보 크롤링
# * site 주소 : http://www.cine21.com/rank/person
# * 개발자 도구에서 xhr 인 것만 필터링 network -> content 페이지의 요청 방식 확인
# * Request URL: http://www.cine21.com/rank/person/content
# * Request Method : Post
# * From Data (1개월치 데이터)
#     - section: actor
#     - period_start: 2020-07
#     - gender: all
#     - page: 1
# * 1 ~ 2년치 데이터를 한꺼번에 크롤링 해서 actors.json 파일로 저장하기

# %%
import requests
from bs4 import BeautifulSoup
import re
import pymongo
from urllib.parse import urljoin

# %% [markdown]
# ### 정규 표현식
# - \w 는 문자와 숫자
# <pre>
#      * : 0 ~ n (횟수), + : 1 ~ n, ? : 0(zero) or 1
# </pre>
# <br>
# <br>
# - .(period) : 줄바꿈 문자(\n)을 제외한 모든 글자 1개를 의미한다.
# - .* 는 문자가 0번 또는 그 이상 반복되는 패턴
# <br>
# <br>
# - Greedy(.\*) vs Non-Greedy(.*?) ex) <span.*?>.*?</span>
#     - Greedy(.\*) (욕심많은) : 모두 선택됨
#     - Non-Greedy(.*?) (욕심없는) : 첫번째 매칭되는 태그만 선택됨
# <br>
# <br>
# - [\n\r\t] : \n, \r, \t 중 하나는 찾는다.
# <br>
# <br>
# - re.compile(r'[\n\r\t]') 는 해당 정규표현식을 찾아주는 컴파일러를 생성해주는 함수이다.
#     - compile 함수 안에 정규표현식 앞에는 항상 r 을 붙여줘야 한다.

# %% [markdown]
# #### 1단계

# %%
actor_url = 'http://www.cine21.com/rank/person/content'

formdata_dict = dict()
formdata_dict['section'] = 'actor'
formdata_dict['period_start'] = '2020-07'
formdata_dict['gender'] = 'all'
formdata_dict['page'] = 1
formdata_dict

res = requests.post(actor_url, data=formdata_dict) #post 방식에는 data속성에 넣어야함 / 통신을 위한 설정
print(res.ok) # 통신확인

soup = BeautifulSoup(res.text, 'html.parser') # html 형식을 파싱할 준비 완료
soup
actor_item_list = list() # 각 배우들을 저장할 list
 # ul > li.people_li > div.name > a
for actor in soup.select('li.people_li div.name'):
    #print(actor)
    print(re.sub('\(\w*\)','',actor.text)) # 정규 표현식 적용

# ------------------------------------------------------------------------------------------

for a_tag in soup.select('li.people_li div.name a'):
    #print(a_tag['href'])
    actor_detail_url = urljoin(actor_url, a_tag['href']) # main_ulr + 각 a_tag['href'] 의 url
    #print(actor_detail_url)

    res = requests.get(actor_detail_url)
    soup = BeautifulSoup(res.text, 'html.parser')

    actor_item_dict = dict()
    for li_tag in soup.select('ul.default_info li'): # a 태그 안에 있는 li 태그들    
        #print(li_tag)
        #print(li_tag.text)

        #dict의 key에 해당하는 값을 추출한다. dict['직업']
        actor_item_field = li_tag.select_one('span.tit').text # 직업
        #print(actor_item_field) # 키 값 확인
        
        #dict의 value에 해당하는 값을 추출한다. dict['직업'] = '배우' 를 뽑아낸다.
        #<li><span class="tit">직업</span>배우</li>
        actor_item_value = re.sub('<span.*?>.*?</span>', '', str(li_tag))  # 값들 span 안에 있는 태그들 정규 표현식으로 파싱 / #<li>배우</li>
        actor_item_value = re.sub('<.*?>', '', actor_item_value) # 배우

        """ 적용 전
        \nhttps://www.facebook.com/cjesminjae
        """

        regex = re.compile(r'[\n\r\t]')
        actor_item_value = regex.sub('', actor_item_value)

        """ 적용 후
        https://www.facebook.com/cjesminjae
        """

        actor_item_dict[actor_item_field] = actor_item_value
        #print(actor_item_dict) # 누적되어 쌓임

    actor_item_list.append(actor_item_dict)

actor_item_list
# Out:
# True
# 강동원
# 이정현
# 이레
# 권해효
# 구교환
# 김민재
# 유아인
# [{'직업': '배우',
#   '생년월일': '1981-01-18',
#   '성별': '남',
#   '홈페이지': 'http://www.gangdongwon.com',
#   '신장/체중': '186cm, 68kg',
#   '학교': '한양대 - 상명대학교대학원 연극영화 (석사과정 재학)',
#   '취미': '음악감상, 웹서핑, 운동, 신발 모으기',
#   '특기': '축구'},
#  {'직업': '배우',
#   '생년월일': '1980-02-07',
#   '성별': '여',
#   '홈페이지': 'https://www.instagram.com/mermaidleejh/https://twitter.com/mermaidjh',
#   '신장/체중': '158cm, 38kg',
#   '학교': '중앙대학교 연극영화',
#   '취미': '바비 인형 수집, 피아노 연주',
#   '특기': '별관찰, 시나리오 쓰기',
#   '소속사': '에이바 앤 엔터테인먼트'},
#  {'직업': '배우',
#   '생년월일': '2006-03-12',
#   '성별': '여',
#   '홈페이지': 'https://www.facebook.com/leere.vv/'},
#  {'직업': '배우',
#   '생년월일': '1965-11-06',
#   '성별': '남',
#   '신장/체중': '170cm, 62kg',
#   '학교': '한양대학교 연극영화학 졸업'},
#  {'직업': '배우', '생년월일': '1982-12-14', '성별': '남'},
#  {'직업': '배우',
#   '생년월일': '1979-03-20',
#   '성별': '남',
#   '홈페이지': 'https://www.facebook.com/cjesminjae',
#   '학교': '한국예술종합학교'},
#  {'다른 이름': '엄홍식',
#   '직업': '배우',
#   '생년월일': '1986-10-06',
#   '성별': '남',
#   '홈페이지': 'https://www.instagram.com/hongsick/https://twitter.com/seeksik',
#   '신장/체중': '178cm, 60kg',
#   '학교': '단국대학교 연극',
#   '취미': '피아노 연주, 인터넷 게임, 영화, 음악감상',
#   '특기': '스노우보드, 수영'}]

# %%
# 정규 표현식 테스트

test_data = '유아인(2편)'
re.sub('\(\w*\)','',test_data) # 정규 표현식 사용 / 앞에 '\(\)' >> ()찾아라 / '' << empty 이걸로 바꿔라
# Out:
# '유아인'

# %%
# 정규 표현식 white space 테스트

# 공백, 탭 등 white space제거
test_data = """
\n
\thttps://www.facebook.com/cjesminjae
\n
학교"""
print(test_data)
regex = re.compile(r'[\n\r\t]') # \n\r\t 이걸 찾아라
regex.sub('',test_data) # 위에 찾은 값들을 공백문자로 대체해라
# Out:
# 	https://www.facebook.com/cjesminjae
#
#
# 학교
# 'https://www.facebook.com/cjesminjae학교'

# %% [markdown]
# #### 2단계
# * 1 page의 7명 배우의 정보를 출력

# %%
# 흥행지수
actor_url = 'http://www.cine21.com/rank/person/content'

formdata_dict = dict()
formdata_dict['section'] = 'actor'
formdata_dict['period_start'] = '2020-07'
formdata_dict['gender'] = 'all'
formdata_dict['page'] = 1
formdata_dict

res = requests.post(actor_url, data=formdata_dict) #post 방식에는 data속성에 넣어야함 / 통신을 위한 설정
print(res.ok) # 통신확인

soup = BeautifulSoup(res.text, 'html.parser') # html 형식을 파싱할 준비 완료
soup

actor_item_list = list() # 각 배우들을 저장할 list

actors = soup.select('li.people_li div.name')
hits = soup.select('ul.num_info > li > strong') # '>' >> 바로 아래에 있다는 표시
movies = soup.select('ul.mov_list')
rankings = soup.select('li.people_li > span.grade') #print(len(rankings))

#actor 변수가 <div class=name> 를 의미함
for index, actor in enumerate(actors): 
    actor_item_dict = dict()
    #print(actor)
    #유아인(2편) 에서 (2편)을 제거하고 저장한다.
    actor_name = re.sub('\(\w*\)','',actor.text)
    actor_item_dict['배우이름'] = actor_name

    #흥행지수 값에서 ,(콤마)를 제거하고 정수타입으로 변환해서 저장한다.
    actor_hit = int(hits[index].text.replace(',', '')) # replace() 함수 : ',' 를 빼주기 위함
    actor_item_dict['흥행지수'] = actor_hit
    #print(artor_name, actor_hit) 배우이름, 흥행지수

    #출연작
    movie_titles = movies[index].select('li a span')
    #출연작 여러개의 title을 저장하는 리스트
    movie_title_list = list()
    for movie_title in movie_titles:
        movie_title_list.append(movie_title.text)
    actor_item_dict['출연영화'] = movie_title_list
    
    #순위
    actor_ranking = rankings[index].text
    actor_item_dict['랭킹'] = int(actor_ranking)
    #print(artor_name, actor_ranking)

# ------------------------------------------------------------------------------------------
    #배우의 상세정보를 보기 위해 http get 요청 다시 요청함
    #('li.people_li div.name a')
    """
        <div class=name> = actors
            <a href="/db/person/info/?person_id=18040"> = actor_detail_url
    """
    actor_detail_url = actor.select_one('a').attrs['href'] #attrs[속성]
    actor_detail_full_url = urljoin(actor_url, actor_detail_url)
   #print(actor_detail_full_url)

    res = requests.get(actor_detail_full_url)
    soup = BeautifulSoup(res.text, 'html.parser')

    for li_tag in soup.select('ul.default_info li'): # a 태그 안에 있는 li 태그들    
        #print(li_tag)
        #print(li_tag.text)

        #dict의 key에 해당하는 값을 추출한다. dict['직업']
        actor_item_field = li_tag.select_one('span.tit').text # 직업
        #print(actor_item_field) # 키 값 확인
        
        #dict의 value에 해당하는 값을 추출한다. dict['직업'] = '배우' 를 뽑아낸다.
        #<li><span class="tit">직업</span>배우</li>
        actor_item_value = re.sub('<span.*?>.*?</span>', '', str(li_tag))  # 값들 span 안에 있는 태그들 정규 표현식으로 파싱 / #<li>배우</li>
        actor_item_value = re.sub('<.*?>', '', actor_item_value) # 배우

        """ 적용 전
        \nhttps://www.facebook.com/cjesminjae
        """

        regex = re.compile(r'[\n\r\t]')
        actor_item_value = regex.sub('', actor_item_value)

        """ 적용 후
        https://www.facebook.com/cjesminjae
        """

        actor_item_dict[actor_item_field] = actor_item_value
        #print(actor_item_dict) # 누적되어 쌓임

    actor_item_list.append(actor_item_dict)

#actor_item_list
# Out:
# True
# [{'배우이름': '강동원',
#   '흥행지수': 159665,
#   '출연영화': ['반도'],
#   '랭킹': 1,
#   '직업': '배우',
#   '생년월일': '1981-01-18',
#   '성별': '남',
#   '홈페이지': 'http://www.gangdongwon.com',
#   '신장/체중': '186cm, 68kg',
#   '학교': '한양대 - 상명대학교대학원 연극영화 (석사과정 재학)',
#   '취미': '음악감상, 웹서핑, 운동, 신발 모으기',
#   '특기': '축구'},
#  {'배우이름': '이정현',
#   '흥행지수': 139707,
#   '출연영화': ['반도'],
#   '랭킹': 2,
#   '직업': '배우',
#   '생년월일': '1980-02-07',
#   '성별': '여',
#   '홈페이지': 'https://www.instagram.com/mermaidleejh/https://twitter.com/mermaidjh',
#   '신장/체중': '158cm, 38kg',
#   '학교': '중앙대학교 연극영화',
#   '취미': '바비 인형 수집, 피아노 연주',
#   '특기': '별관찰, 시나리오 쓰기',
#   '소속사': '에이바 앤 엔터테인먼트'},
#  {'배우이름': '이레',
#   '흥행지수': 119748,
#   '출연영화': ['반도'],
#   '랭킹': 3,
#   '직업': '배우',
#   '생년월일': '2006-03-12',
#   '성별': '여',
#   '홈페이지': 'https://www.facebook.com/leere.vv/'},
#  {'배우이름': '권해효',
#   '흥행지수': 99795,
#   '출연영화': ['반도', '사이비', '한낮의 피크닉'],
#   '랭킹': 4,
#   '직업': '배우',
#   '생년월일': '1965-11-06',
#   '성별': '남',
#   '신장/체중': '170cm, 62kg',
#   '학교': '한양대학교 연극영화학 졸업'},
#  {'배우이름': '구교환',
#   '흥행지수': 79832,
#   '출연영화': ['반도'],
#   '랭킹': 5,
#   '직업': '배우',
#   '생년월일': '1982-12-14',
#   '성별': '남'},
#  {'배우이름': '김민재',
#   '흥행지수': 59874,
#   '출연영화': ['반도'],
#   '랭킹': 6,
#   '직업': '배우',
#   '생년월일': '1979-03-20',
#   '성별': '남',
#   '홈페이지': 'https://www.facebook.com/cjesminjae',
#   '학교': '한국예술종합학교'},
#  {'배우이름': '유아인',
#   '흥행지수': 54589,
#   '출연영화': ['＃살아있다', '버닝'],
#   '랭킹': 7,
#   '다른 이름': '엄홍식',
#   '직업': '배우',
#   '생년월일': '1986-10-06',
#   '성별': '남',
#   '홈페이지': 'https://www.instagram.com/hongsick/https://twitter.com/seeksik',
#   '신장/체중': '178cm, 60kg',
#   '학교': '단국대학교 연극',
#   '취미': '피아노 연주, 인터넷 게임, 영화, 음악감상',
#   '특기': '스노우보드, 수영'}]

# %% [markdown]
# #### 3단계
# * 1, 2, 3 페이지의 21명 배우의 정보를 출력

# %%
actor_url = 'http://www.cine21.com/rank/person/content'

formdata_dict = dict()
formdata_dict['section'] = 'actor'
formdata_dict['period_start'] = '2020-07'
formdata_dict['gender'] = 'all'

actor_item_list = list() # 21명 다 저장할 list

for page in range(1, 4): # 3페이지까지
    formdata_dict['page'] = page
    print('---> {} 페이지 출력됨'.format(page))

    res = requests.post(actor_url, data=formdata_dict) #post 방식에는 data속성에 넣어야함 / 통신을 위한 설정

    soup = BeautifulSoup(res.text, 'html.parser') # html 형식을 파싱할 준비 완료
    soup

    actors = soup.select('li.people_li div.name')
    hits = soup.select('ul.num_info > li > strong') # '>' >> 바로 아래에 있다는 표시
    movies = soup.select('ul.mov_list')
    rankings = soup.select('li.people_li > span.grade') #print(len(rankings))

    #actor 변수가 <div class=name> 를 의미함 / 배우
    for index, actor in enumerate(actors):
        print('===> {} 번째 배우 출력됨'.format(index+1))
        actor_item_dict = dict()
        #print(actor)
        #유아인(2편) 에서 (2편)을 제거하고 저장한다.
        actor_name = re.sub('\(\w*\)','',actor.text)
        actor_item_dict['배우이름'] = actor_name

        #흥행지수 값에서 ,(콤마)를 제거하고 정수타입으로 변환해서 저장한다.
        actor_hit = int(hits[index].text.replace(',', '')) # replace() 함수 : ',' 를 빼주기 위함
        actor_item_dict['흥행지수'] = actor_hit
        #print(artor_name, actor_hit) 배우이름, 흥행지수

        #출연작
        movie_titles = movies[index].select('li a span')
        #출연작 여러개의 title을 저장하는 리스트
        movie_title_list = list()
        for movie_title in movie_titles:
            movie_title_list.append(movie_title.text)
        actor_item_dict['출연영화'] = movie_title_list
        
        #순위
        actor_ranking = rankings[index].text
        actor_item_dict['랭킹'] = int(actor_ranking)
        #print(artor_name, actor_ranking)

    # ------------------------------------------------------------------------------------------
        #배우의 상세정보를 보기 위해 http get 요청 다시 요청함
        #('li.people_li div.name a')
        """
            <div class=name> = actors
                <a href="/db/person/info/?person_id=18040"> = actor_detail_url
        """
        actor_detail_url = actor.select_one('a').attrs['href'] #attrs[속성]
        actor_detail_full_url = urljoin(actor_url, actor_detail_url)
    #print(actor_detail_full_url)

        res = requests.get(actor_detail_full_url)
        soup = BeautifulSoup(res.text, 'html.parser')

        for li_tag in soup.select('ul.default_info li'): # a 태그 안에 있는 li 태그들    
            #print(li_tag)
            #print(li_tag.text)

            #dict의 key에 해당하는 값을 추출한다. dict['직업']
            actor_item_field = li_tag.select_one('span.tit').text # 직업
            #print(actor_item_field) # 키 값 확인
            
            #dict의 value에 해당하는 값을 추출한다. dict['직업'] = '배우' 를 뽑아낸다.
            #<li><span class="tit">직업</span>배우</li>
            actor_item_value = re.sub('<span.*?>.*?</span>', '', str(li_tag))  # 값들 span 안에 있는 태그들 정규 표현식으로 파싱 / #<li>배우</li>
            actor_item_value = re.sub('<.*?>', '', actor_item_value) # 배우

            """ 적용 전
            \nhttps://www.facebook.com/cjesminjae
            """

            regex = re.compile(r'[\n\r\t]')
            actor_item_value = regex.sub('', actor_item_value)

            """ 적용 후
            https://www.facebook.com/cjesminjae
            """

            actor_item_dict[actor_item_field] = actor_item_value
            #print(actor_item_dict) # 누적되어 쌓임

        actor_item_list.append(actor_item_dict)

print(len(actor_item_list))
actor_item_list
# Out:
# ---> 1 페이지 출력됨
# ===> 1 번째 배우 출력됨
# ===> 2 번째 배우 출력됨
# ===> 3 번째 배우 출력됨
# ===> 4 번째 배우 출력됨
# ===> 5 번째 배우 출력됨
# ===> 6 번째 배우 출력됨
# ===> 7 번째 배우 출력됨
# ---> 2 페이지 출력됨
# ===> 1 번째 배우 출력됨
# ===> 2 번째 배우 출력됨
# ===> 3 번째 배우 출력됨
# ===> 4 번째 배우 출력됨
# ===> 5 번째 배우 출력됨
# ===> 6 번째 배우 출력됨
# ===> 7 번째 배우 출력됨
# ---> 3 페이지 출력됨
# ===> 1 번째 배우 출력됨
# ===> 2 번째 배우 출력됨
# ===> 3 번째 배우 출력됨
# ===> 4 번째 배우 출력됨
# ===> 5 번째 배우 출력됨
# ===> 6 번째 배우 출력됨
# ===> 7 번째 배우 출력됨
# 21
# [{'배우이름': '강동원',
#   '흥행지수': 159665,
#   '출연영화': ['반도'],
#   '랭킹': 1,
#   '직업': '배우',
#   '생년월일': '1981-01-18',
#   '성별': '남',
#   '홈페이지': 'http://www.gangdongwon.com',
#   '신장/체중': '186cm, 68kg',
#   '학교': '한양대 - 상명대학교대학원 연극영화 (석사과정 재학)',
#   '취미': '음악감상, 웹서핑, 운동, 신발 모으기',
#   '특기': '축구'},
#  {'배우이름': '이정현',
#   '흥행지수': 139707,
#   '출연영화': ['반도'],
#   '랭킹': 2,
#   '직업': '배우',
#   '생년월일': '1980-02-07',
#   '성별': '여',
#   '홈페이지': 'https://www.instagram.com/mermaidleejh/https://twitter.com/mermaidjh',
#   '신장/체중': '158cm, 38kg',
#   '학교': '중앙대학교 연극영화',
#   '취미': '바비 인형 수집, 피아노 연주',
#   '특기': '별관찰, 시나리오 쓰기',
#   '소속사': '에이바 앤 엔터테인먼트'},
#  {'배우이름': '이레',
#   '흥행지수': 119748,
#   '출연영화': ['반도'],
#   '랭킹': 3,
#   '직업': '배우',
#   '생년월일': '2006-03-12',
#   '성별': '여',
#   '홈페이지': 'https://www.facebook.com/leere.vv/'},
#  {'배우이름': '권해효',
#   '흥행지수': 99795,
#   '출연영화': ['반도', '사이비', '한낮의 피크닉'],
#   '랭킹': 4,
#   '직업': '배우',
#   '생년월일': '1965-11-06',
#   '성별': '남',
#   '신장/체중': '170cm, 62kg',
#   '학교': '한양대학교 연극영화학 졸업'},
#  {'배우이름': '구교환',
#   '흥행지수': 79832,
#   '출연영화': ['반도'],
#   '랭킹': 5,
#   '직업': '배우',
#   '생년월일': '1982-12-14',
#   '성별': '남'},
#  {'배우이름': '김민재',
#   '흥행지수': 59874,
#   '출연영화': ['반도'],
#   '랭킹': 6,
#   '직업': '배우',
#   '생년월일': '1979-03-20',
#   '성별': '남',
#   '홈페이지': 'https://www.facebook.com/cjesminjae',
#   '학교': '한국예술종합학교'},
#  {'배우이름': '유아인',
#   '흥행지수': 54589,
#   '출연영화': ['＃살아있다', '버닝'],
#   '랭킹': 7,
#   '다른 이름': '엄홍식',
#   '직업': '배우',
#   '생년월일': '1986-10-06',
#   '성별': '남',
#   '홈페이지': 'https://www.instagram.com/hongsick/https://twitter.com/seeksik',
#   '신장/체중': '178cm, 60kg',
#   '학교': '단국대학교 연극',
#   '취미': '피아노 연주, 인터넷 게임, 영화, 음악감상',
#   '특기': '스노우보드, 수영'},
#  {'배우이름': '박신혜',
#   '흥행지수': 43667,
#   '출연영화': ['＃살아있다'],
#   '랭킹': 8,
#   '직업': '배우',
#   '생년월일': '1990-02-18',
#   '성별': '여',
#   '홈페이지': 'https://twitter.com/ssinzhttps://www.instagram.com/ssinz7/',
#   '신장/체중': '165cm, 45kg',
#   '학교': '중앙대학교 연극영화학 (재학)',
#   '취미': '음악감상',
#   '특기': '댄스',
#   '소속사': '아바 엔터테인먼트'},
#  {'배우이름': '김도윤',
#   '흥행지수': 39916,
#   '출연영화': ['반도'],
#   '랭킹': 9,
#   '다른 이름': '김주년',
#   '직업': '배우',
#   '생년월일': '1981-08-07',
#   '성별': '남'},
#  {'배우이름': '전배수',
#   '흥행지수': 32750,
#   '출연영화': ['＃살아있다'],
#   '랭킹': 10,
#   '직업': '배우',
#   '생년월일': '1970-06-02',
#   '성별': '남'},
#  {'배우이름': '이현욱',
#   '흥행지수': 21833,
#   '출연영화': ['＃살아있다'],
#   '랭킹': 11,
#   '직업': '배우',
#   '생년월일': '1985-06-17',
#   '성별': '남',
#   '신장/체중': '180cm, 68kg'},
#  {'배우이름': '오혜원',
#   '흥행지수': 10917,
#   '출연영화': ['＃살아있다'],
#   '랭킹': 12,
#   '직업': '모델',
#   '성별': '여',
#   '홈페이지': 'http://www.vlive.tv/channels/E29393'},
#  {'배우이름': '정우성',
#   '흥행지수': 9329,
#   '출연영화': ['강철비2: 정상회담', '호우시절'],
#   '랭킹': 13,
#   '직업': '배우',
#   '성별': '남',
#   '홈페이지': 'http://www.artistcompany.co.kr/portfolio-item/jung-woo-sung/',
#   '소속사': '아티스트컴퍼니'},
#  {'배우이름': '곽도원',
#   '흥행지수': 8771,
#   '출연영화': ['강철비2: 정상회담'],
#   '랭킹': 14,
#   '다른 이름': '곽병규',
#   '직업': '배우',
#   '생년월일': '1974-00-00',
#   '성별': '남',
#   '홈페이지': 'https://www.facebook.com/cjesdowonhttp://twitter.com/kwakbyoungkuy'},
#  {'배우이름': '유연석',
#   '흥행지수': 8222,
#   '출연영화': ['강철비2: 정상회담'],
#   '랭킹': 15,
#   '다른 이름': '안연석',
#   '직업': '배우',
#   '생년월일': '1984-04-11',
#   '성별': '남',
#   '홈페이지': 'https://twitter.com/yeonseok411https://www.instagram.com/yoo_yeonseok/',
#   '소속사': '이야기엔터테인먼트'},
#  {'배우이름': '신정근',
#   '흥행지수': 7674,
#   '출연영화': ['강철비2: 정상회담'],
#   '랭킹': 16,
#   '직업': '배우',
#   '성별': '남',
#   '홈페이지': 'http://www.artistcompany.co.kr/portfolio-item/shin-jung-geun/',
#   '소속사': '아티스트컴퍼니'},
#  {'배우이름': '류수영',
#   '흥행지수': 7126,
#   '출연영화': ['강철비2: 정상회담'],
#   '랭킹': 17,
#   '다른 이름': '어남선',
#   '직업': '배우',
#   '생년월일': '1979-09-05',
#   '성별': '남',
#   '홈페이지': 'https://twitter.com/sienarollhttps://instagram.com/suyoung_ryu/',
#   '신장/체중': '183cm, 69kg',
#   '학교': '명지대학교 경영학',
#   '취미': '지점토공예, 운동(구기종목)',
#   '특기': '합기도, 스쿼시'},
#  {'배우이름': '염정아',
#   '흥행지수': 6578,
#   '출연영화': ['강철비2: 정상회담'],
#   '랭킹': 18,
#   '직업': '배우',
#   '성별': '여',
#   '홈페이지': 'http://www.artistcompany.co.kr/portfolio-item/yum-jung-ah/',
#   '소속사': '아티스트컴퍼니'},
#  {'배우이름': '김용림',
#   '흥행지수': 6030,
#   '출연영화': ['강철비2: 정상회담'],
#   '랭킹': 19,
#   '직업': '배우',
#   '생년월일': '1940-03-03',
#   '성별': '여'},
#  {'배우이름': '김명곤',
#   '흥행지수': 5482,
#   '출연영화': ['강철비2: 정상회담', '물의 기억'],
#   '랭킹': 20,
#   '직업': '배우',
#   '생년월일': '1952-12-03',
#   '성별': '남',
#   '홈페이지': 'https://twitter.com/myunggon'},
#  {'배우이름': '장광',
#   '흥행지수': 4933,
#   '출연영화': ['강철비2: 정상회담'],
#   '랭킹': 21,
#   '직업': '배우',
#   '생년월일': '1952-01-05',
#   '성별': '남'}]

# %% [markdown]
# #### 4단계
# * 1년치 데이터 1905명 배우의 정보를 출력

# %%
import requests
from bs4 import BeautifulSoup
import re
import pymongo
from urllib.parse import urljoin
from itertools import count # itertools 내부함수

actor_url = 'http://www.cine21.com/rank/person/content'

formdata_dict = dict()
formdata_dict['section'] = 'actor'
formdata_dict['period_start'] = '2019-07'
formdata_dict['gender'] = 'all'

actor_item_list = list() # 21명 다 저장할 list

#for page in range(1, 4): # 3페이지까지
for page in count(1): # 끝까지 돈다.
    formdata_dict['page'] = page
    print('---> {} 페이지 출력됨'.format(page))

    res = requests.post(actor_url, data=formdata_dict) #post 방식에는 data속성에 넣어야함 / 통신을 위한 설정

    soup = BeautifulSoup(res.text, 'html.parser') # html 형식을 파싱할 준비 완료
    soup

    actors = soup.select('li.people_li div.name')
    if len(actors) == 0:
        break
    hits = soup.select('ul.num_info > li > strong') # '>' >> 바로 아래에 있다는 표시
    movies = soup.select('ul.mov_list')
    rankings = soup.select('li.people_li > span.grade') #print(len(rankings))

    #actor 변수가 <div class=name> 를 의미함 / 배우
    for index, actor in enumerate(actors):
        actor_item_dict = dict()
        #print(actor)
        #유아인(2편) 에서 (2편)을 제거하고 저장한다.
        actor_name = re.sub('\(\w*\)','',actor.text)
        actor_item_dict['배우이름'] = actor_name
        print('===> {}({}) 배우 출력됨'.format(actor_name, len(actor_name)))

        #흥행지수 값에서 ,(콤마)를 제거하고 정수타입으로 변환해서 저장한다.
        actor_hit = int(hits[index].text.replace(',', '')) # replace() 함수 : ',' 를 빼주기 위함
        actor_item_dict['흥행지수'] = actor_hit
        #print(artor_name, actor_hit) 배우이름, 흥행지수

        #출연작
        movie_titles = movies[index].select('li a span')
        #출연작 여러개의 title을 저장하는 리스트
        movie_title_list = list()
        for movie_title in movie_titles:
            movie_title_list.append(movie_title.text)
        actor_item_dict['출연영화'] = movie_title_list
        
        #순위
        actor_ranking = rankings[index].text
        actor_item_dict['랭킹'] = int(actor_ranking)
        #print(artor_name, actor_ranking)

    # ------------------------------------------------------------------------------------------
        #배우의 상세정보를 보기 위해 http get 요청 다시 요청함
        #('li.people_li div.name a')
        """
            <div class=name> = actors
                <a href="/db/person/info/?person_id=18040"> = actor_detail_url
        """
        actor_detail_url = actor.select_one('a').attrs['href'] #attrs[속성]
        actor_detail_full_url = urljoin(actor_url, actor_detail_url)
    #print(actor_detail_full_url)

        res = requests.get(actor_detail_full_url)
        soup = BeautifulSoup(res.text, 'html.parser')

        for li_tag in soup.select('ul.default_info li'): # a 태그 안에 있는 li 태그들    
            #print(li_tag)
            #print(li_tag.text)

            #dict의 key에 해당하는 값을 추출한다. dict['직업']
            actor_item_field = li_tag.select_one('span.tit').text # 직업
            #print(actor_item_field) # 키 값 확인
            
            #dict의 value에 해당하는 값을 추출한다. dict['직업'] = '배우' 를 뽑아낸다.
            #<li><span class="tit">직업</span>배우</li>
            actor_item_value = re.sub('<span.*?>.*?</span>', '', str(li_tag))  # 값들 span 안에 있는 태그들 정규 표현식으로 파싱 / #<li>배우</li>
            actor_item_value = re.sub('<.*?>', '', actor_item_value) # 배우

            """ 적용 전
            \nhttps://www.facebook.com/cjesminjae
            """

            regex = re.compile(r'[\n\r\t]')
            actor_item_value = regex.sub('', actor_item_value)

            """ 적용 후
            https://www.facebook.com/cjesminjae
            """

            actor_item_dict[actor_item_field] = actor_item_value
            #print(actor_item_dict) # 누적되어 쌓임

        actor_item_list.append(actor_item_dict)

print(len(actor_item_list))
actor_item_list
# Out:
# ---> 1 페이지 출력됨
# ===> 이병헌(3) 배우 출력됨
# ===> 하정우(3) 배우 출력됨
# ===> 마동석(3) 배우 출력됨
# ===> 전혜진(3) 배우 출력됨
# ===> 이성민(3) 배우 출력됨
# ===> 김아중(3) 배우 출력됨
# ===> 박정민(3) 배우 출력됨
# ---> 2 페이지 출력됨
# ===> 강기영(3) 배우 출력됨
# ===> 조진웅(3) 배우 출력됨
# ===> 조정석(3) 배우 출력됨
# ===> 배수지(3) 배우 출력됨
# ===> 유아인(3) 배우 출력됨
# ===> 임윤아(3) 배우 출력됨
# ===> 고두심(3) 배우 출력됨
# ---> 3 페이지 출력됨
# ===> 장기용(3) 배우 출력됨
# ===> 권상우(3) 배우 출력됨
# ===> 곽도원(3) 배우 출력됨
# ===> 유해진(3) 배우 출력됨
# ===> 최유화(3) 배우 출력됨
# ===> 박인환(3) 배우 출력됨
# ===> 정해인(3) 배우 출력됨
# ---> 4 페이지 출력됨
# ===> 정유미(3) 배우 출력됨
# ===> 김지영(3) 배우 출력됨
# ===> 류준열(3) 배우 출력됨
# ===> 이봉련(3) 배우 출력됨
# ===> 조우진(3) 배우 출력됨
# ===> 공유(2) 배우 출력됨
# ===> 강동원(3) 배우 출력됨
# ---> 5 페이지 출력됨
# ===> 김종구(3) 배우 출력됨
# ===> 박지환(3) 배우 출력됨
# ===> 이정현(3) 배우 출력됨
# ===> 김상중(3) 배우 출력됨
# ===> 이희준(3) 배우 출력됨
# ===> 김미경(3) 배우 출력됨
# ===> 허성태(3) 배우 출력됨
# ---> 6 페이지 출력됨
# ===> 김병순(3) 배우 출력됨
# ===> 박신혜(3) 배우 출력됨
# ===> 염정아(3) 배우 출력됨
# ===> 배성우(3) 배우 출력됨
# ===> 이경영(3) 배우 출력됨
# ===> 허준호(3) 배우 출력됨
# ===> 권해효(3) 배우 출력됨
# ---> 7 페이지 출력됨
# ===> 황효은(3) 배우 출력됨
# ===> 이레(2) 배우 출력됨
# ===> 이하늬(3) 배우 출력됨
# ===> 김래원(3) 배우 출력됨
# ===> 공민정(3) 배우 출력됨
# ===> 성유빈(3) 배우 출력됨
# ===> 우도환(3) 배우 출력됨
# ---> 8 페이지 출력됨
# ===> 공효진(3) 배우 출력됨
# ===> 최성은(3) 배우 출력됨
# ===> 박해준(3) 배우 출력됨
# ===> 윤경호(3) 배우 출력됨
# ===> 조한철(3) 배우 출력됨
# ===> 김무열(3) 배우 출력됨
# ===> 김남길(3) 배우 출력됨
# ---> 9 페이지 출력됨
# ===> 성동일(3) 배우 출력됨
# ===> 류승범(3) 배우 출력됨
# ===> 박성연(3) 배우 출력됨
# ===> 김희원(3) 배우 출력됨
# ===> 정민성(3) 배우 출력됨
# ===> 정준호(3) 배우 출력됨
# ===> 김종수(3) 배우 출력됨
# ---> 10 페이지 출력됨
# ===> 강신일(3) 배우 출력됨
# ===> 정웅인(3) 배우 출력됨
# ===> 설경구(3) 배우 출력됨
# ===> 최덕문(3) 배우 출력됨
# ===> 안재홍(3) 배우 출력됨
# ===> 이재인(3) 배우 출력됨
# ===> 김성철(3) 배우 출력됨
# ---> 11 페이지 출력됨
# ===> 구교환(3) 배우 출력됨
# ===> 황우슬혜(4) 배우 출력됨
# ===> 김소진(3) 배우 출력됨
# ===> 김성균(3) 배우 출력됨
# ===> 양정화(3) 배우 출력됨
# ===> 박성일(3) 배우 출력됨
# ===> 장영남(3) 배우 출력됨
# ---> 12 페이지 출력됨
# ===> 장소연(3) 배우 출력됨
# ===> 박서준(3) 배우 출력됨
# ===> 한정현(3) 배우 출력됨
# ===> 나문희(3) 배우 출력됨
# ===> 우현(2) 배우 출력됨
# ===> 이이경(3) 배우 출력됨
# ===> 정인겸(3) 배우 출력됨
# ---> 13 페이지 출력됨
# ===> 강소라(3) 배우 출력됨
# ===> 윤제문(3) 배우 출력됨
# ===> 최민식(3) 배우 출력됨
# ===> 주민경(3) 배우 출력됨
# ===> 조현정(3) 배우 출력됨
# ===> 배유람(3) 배우 출력됨
# ===> 김민재(3) 배우 출력됨
# ---> 14 페이지 출력됨
# ===> 이지원(3) 배우 출력됨
# ===> 송강호(3) 배우 출력됨
# ===> 한석규(3) 배우 출력됨
# ===> 안성기(3) 배우 출력됨
# ===> 김고은(3) 배우 출력됨
# ===> 차승원(3) 배우 출력됨
# ===> 김혜준(3) 배우 출력됨
# ---> 15 페이지 출력됨
# ===> 라미란(3) 배우 출력됨
# ===> 박영규(3) 배우 출력됨
# ===> 신구(2) 배우 출력됨
# ===> 이채은(3) 배우 출력됨
# ===> 허율(2) 배우 출력됨
# ===> 김홍파(3) 배우 출력됨
# ===> 이광수(3) 배우 출력됨
# ---> 16 페이지 출력됨
# ===> 유수빈(3) 배우 출력됨
# ===> 이상원(3) 배우 출력됨
# ===> 김혜옥(3) 배우 출력됨
# ===> 전여빈(3) 배우 출력됨
# ===> 김경덕(3) 배우 출력됨
# ===> 김사랑(3) 배우 출력됨
# ===> 정혜린(3) 배우 출력됨
# ---> 17 페이지 출력됨
# ===> 신용우(3) 배우 출력됨
# ===> 김명민(3) 배우 출력됨
# ===> 김성오(3) 배우 출력됨
# ===> 박지현(3) 배우 출력됨
# ===> 김도윤(3) 배우 출력됨
# ===> 조운(2) 배우 출력됨
# ===> 옥자연(3) 배우 출력됨
# ---> 18 페이지 출력됨
# ===> 김영은(3) 배우 출력됨
# ===> 진선규(3) 배우 출력됨
# ===> 조이현(3) 배우 출력됨
# ===> 김태우(3) 배우 출력됨
# ===> 고창석(3) 배우 출력됨
# ===> 허동원(3) 배우 출력됨
# ===> 송지효(3) 배우 출력됨
# ---> 19 페이지 출력됨
# ===> 최민호(3) 배우 출력됨
# ===> 서예지(3) 배우 출력됨
# ===> 안길강(3) 배우 출력됨
# ===> 장동주(3) 배우 출력됨
# ===> 한수현(3) 배우 출력됨
# ===> 김국희(3) 배우 출력됨
# ===> 임지연(3) 배우 출력됨
# ---> 20 페이지 출력됨
# ===> 원현준(3) 배우 출력됨
# ===> 김강훈(3) 배우 출력됨
# ===> 김원해(3) 배우 출력됨
# ===> 신혜선(3) 배우 출력됨
# ===> 전배수(3) 배우 출력됨
# ===> 정지훈(3) 배우 출력됨
# ===> 송영창(3) 배우 출력됨
# ---> 21 페이지 출력됨
# ===> 이영애(3) 배우 출력됨
# ===> 손우현(3) 배우 출력됨
# ===> 정우성(3) 배우 출력됨
# ===> 강신철(3) 배우 출력됨
# ===> 전혜빈(3) 배우 출력됨
# ===> 신세휘(3) 배우 출력됨
# ===> 배종옥(3) 배우 출력됨
# ---> 22 페이지 출력됨
# ===> 김인권(3) 배우 출력됨
# ===> 김채하(3) 배우 출력됨
# ===> 임원희(3) 배우 출력됨
# ===> 엄상현(3) 배우 출력됨
# ===> 이선균(3) 배우 출력됨
# ===> 시영준(3) 배우 출력됨
# ===> 박해수(3) 배우 출력됨
# ---> 23 페이지 출력됨
# ===> 손현주(3) 배우 출력됨
# ===> 장혜진(3) 배우 출력됨
# ===> 정유진(3) 배우 출력됨
# ===> 온주완(3) 배우 출력됨
# ===> 남문철(3) 배우 출력됨
# ===> 유재명(3) 배우 출력됨
# ===> 곽시양(3) 배우 출력됨
# ---> 24 페이지 출력됨
# ===> 박해일(3) 배우 출력됨
# ===> 정해균(3) 배우 출력됨
# ===> 예수정(3) 배우 출력됨
# ===> 조경이(3) 배우 출력됨
# ===> 류한비(3) 배우 출력됨
# ===> 심희섭(3) 배우 출력됨
# ===> 오광록(3) 배우 출력됨
# ---> 25 페이지 출력됨
# ===> 홍경(2) 배우 출력됨
# ===> 박희순(3) 배우 출력됨
# ===> 전미선(3) 배우 출력됨
# ===> 이지현(3) 배우 출력됨
# ===> 전도연(3) 배우 출력됨
# ===> 이얼(2) 배우 출력됨
# ===> 박소담(3) 배우 출력됨
# ---> 26 페이지 출력됨
# ===> 장지건(3) 배우 출력됨
# ===> 박상훈(3) 배우 출력됨
# ===> 이현욱(3) 배우 출력됨
# ===> 최준영(3) 배우 출력됨
# ===> 손종학(3) 배우 출력됨
# ===> 태항호(3) 배우 출력됨
# ===> 김수안(3) 배우 출력됨
# ---> 27 페이지 출력됨
# ===> 박근록(3) 배우 출력됨
# ===> 김상호(3) 배우 출력됨
# ===> 서현우(3) 배우 출력됨
# ===> 이준혁(3) 배우 출력됨
# ===> RM(2) 배우 출력됨
# ===> 안소이(3) 배우 출력됨
# ===> 이현(2) 배우 출력됨
# ---> 28 페이지 출력됨
# ===> 박성훈(3) 배우 출력됨
# ===> 윤여정(3) 배우 출력됨
# ===> 이호정(3) 배우 출력됨
# ===> 이원근(3) 배우 출력됨
# ===> 배정남(3) 배우 출력됨
# ===> 최광일(3) 배우 출력됨
# ===> 박철민(3) 배우 출력됨
# ---> 29 페이지 출력됨
# ===> 최우식(3) 배우 출력됨
# ===> 김준한(3) 배우 출력됨
# ===> 진(1) 배우 출력됨
# ===> 갈소원(3) 배우 출력됨
# ===> 사문영(3) 배우 출력됨
# ===> 박동혁(3) 배우 출력됨
# ===> 천우희(3) 배우 출력됨
# ---> 30 페이지 출력됨
# ===> 김응수(3) 배우 출력됨
# ===> 조여정(3) 배우 출력됨
# ===> 최원영(3) 배우 출력됨
# ===> 고규필(3) 배우 출력됨
# ===> 지현준(3) 배우 출력됨
# ===> 송새벽(3) 배우 출력됨
# ===> 김시아(3) 배우 출력됨
# ---> 31 페이지 출력됨
# ===> 이승희(3) 배우 출력됨
# ===> 전진아(3) 배우 출력됨
# ===> 김서형(3) 배우 출력됨
# ===> 정만식(3) 배우 출력됨
# ===> 이재욱(3) 배우 출력됨
# ===> 권성혁(3) 배우 출력됨
# ===> 김현지(3) 배우 출력됨
# ---> 32 페이지 출력됨
# ===> 최귀화(3) 배우 출력됨
# ===> 신하균(3) 배우 출력됨
# ===> 슈가(2) 배우 출력됨
# ===> 유열(2) 배우 출력됨
# ===> 정재헌(3) 배우 출력됨
# ===> 김복동(3) 배우 출력됨
# ===> 지승현(3) 배우 출력됨
# ---> 33 페이지 출력됨
# ===> 최한(2) 배우 출력됨
# ===> 박혁권(3) 배우 출력됨
# ===> 조수향(3) 배우 출력됨
# ===> 박성근(3) 배우 출력됨
# ===> 정지소(3) 배우 출력됨
# ===> 신현빈(3) 배우 출력됨
# ===> 안내상(3) 배우 출력됨
# ---> 34 페이지 출력됨
# ===> 변희봉(3) 배우 출력됨
# ===> 최상훈(3) 배우 출력됨
# ===> 동방우(3) 배우 출력됨
# ===> 성지루(3) 배우 출력됨
# ===> 유인나(3) 배우 출력됨
# ===> 윤세웅(3) 배우 출력됨
# ===> 차순배(3) 배우 출력됨
# ---> 35 페이지 출력됨
# ===> 김슬기(3) 배우 출력됨
# ===> 사성웅(3) 배우 출력됨
# ===> 유선(2) 배우 출력됨
# ===> 오동민(3) 배우 출력됨
# ===> 임한빈(3) 배우 출력됨
# ===> 유호한(3) 배우 출력됨
# ===> 박지일(3) 배우 출력됨
# ---> 36 페이지 출력됨
# ===> 박지일(3) 배우 출력됨
# ===> 신수연(3) 배우 출력됨
# ===> 정혜원(3) 배우 출력됨
# ===> 차래형(3) 배우 출력됨
# ===> 오혜원(3) 배우 출력됨
# ===> 김수미(3) 배우 출력됨
# ===> 정가람(3) 배우 출력됨
# ---> 37 페이지 출력됨
# ===> 지일주(3) 배우 출력됨
# ===> 김용림(3) 배우 출력됨
# ===> 홍진욱(3) 배우 출력됨
# ===> 전광주(3) 배우 출력됨
# ===> 남도형(3) 배우 출력됨
# ===> 정현준(3) 배우 출력됨
# ===> 이중옥(3) 배우 출력됨
# ---> 38 페이지 출력됨
# ===> 준호(2) 배우 출력됨
# ===> 심규혁(3) 배우 출력됨
# ===> 윤정일(3) 배우 출력됨
# ===> 윤세아(3) 배우 출력됨
# ===> 강보경(3) 배우 출력됨
# ===> 이태형(3) 배우 출력됨
# ===> 정소민(3) 배우 출력됨
# ---> 39 페이지 출력됨
# ===> 소연(2) 배우 출력됨
# ===> 임형국(3) 배우 출력됨
# ===> 이종구(3) 배우 출력됨
# ===> 배수빈(3) 배우 출력됨
# ===> 김영재(3) 배우 출력됨
# ===> 이항나(3) 배우 출력됨
# ===> 진경(2) 배우 출력됨
# ---> 40 페이지 출력됨
# ===> 지민(2) 배우 출력됨
# ===> 유연석(3) 배우 출력됨
# ===> 정인기(3) 배우 출력됨
# ===> 임채헌(3) 배우 출력됨
# ===> 정상훈(3) 배우 출력됨
# ===> 김새벽(3) 배우 출력됨
# ===> 윤박(2) 배우 출력됨
# ---> 41 페이지 출력됨
# ===> 이시언(3) 배우 출력됨
# ===> 이정은(3) 배우 출력됨
# ===> 이찬유(3) 배우 출력됨
# ===> 장혁진(3) 배우 출력됨
# ===> 정승욱(3) 배우 출력됨
# ===> 김혜성(3) 배우 출력됨
# ===> 신정근(3) 배우 출력됨
# ---> 42 페이지 출력됨
# ===> 예지원(3) 배우 출력됨
# ===> 김리흔(3) 배우 출력됨
# ===> 탕준상(3) 배우 출력됨
# ===> 김희애(3) 배우 출력됨
# ===> 류수영(3) 배우 출력됨
# ===> 김소희(3) 배우 출력됨
# ===> 서반석(3) 배우 출력됨
# ---> 43 페이지 출력됨
# ===> 김보나(3) 배우 출력됨
# ===> 서문석(3) 배우 출력됨
# ===> 한지민(3) 배우 출력됨
# ===> 김지혜(3) 배우 출력됨
# ===> 진선미(3) 배우 출력됨
# ===> 주석태(3) 배우 출력됨
# ===> 공명(2) 배우 출력됨
# ---> 44 페이지 출력됨
# ===> 김은아(3) 배우 출력됨
# ===> 이순재(3) 배우 출력됨
# ===> 이경훈(3) 배우 출력됨
# ===> 한이진(3) 배우 출력됨
# ===> 김소혜(3) 배우 출력됨
# ===> 차수연(3) 배우 출력됨
# ===> 전노민(3) 배우 출력됨
# ---> 45 페이지 출력됨
# ===> 이태석(3) 배우 출력됨
# ===> 이종혁(3) 배우 출력됨
# ===> 박지후(3) 배우 출력됨
# ===> 백주희(3) 배우 출력됨
# ===> 뷔(1) 배우 출력됨
# ===> 김명곤(3) 배우 출력됨
# ===> 박지윤(3) 배우 출력됨
# ---> 46 페이지 출력됨
# ===> 금새록(3) 배우 출력됨
# ===> 이일화(3) 배우 출력됨
# ===> 박영진(3) 배우 출력됨
# ===> 장광(2) 배우 출력됨
# ===> 진유영(3) 배우 출력됨
# ===> 정유정(3) 배우 출력됨
# ===> 이선빈(3) 배우 출력됨
# ---> 47 페이지 출력됨
# ===> 민경진(3) 배우 출력됨
# ===> 이창훈(3) 배우 출력됨
# ===> 박호산(3) 배우 출력됨
# ===> 이승연(3) 배우 출력됨
# ===> 강은애(3) 배우 출력됨
# ===> 박영재(3) 배우 출력됨
# ===> 방연지(3) 배우 출력됨
# ---> 48 페이지 출력됨
# ===> 김보성(3) 배우 출력됨
# ===> 심완준(3) 배우 출력됨
# ===> 김보라(3) 배우 출력됨
# ===> 정애화(3) 배우 출력됨
# ===> 김승훈(3) 배우 출력됨
# ===> 이재용(3) 배우 출력됨
# ===> 배정화(3) 배우 출력됨
# ---> 49 페이지 출력됨
# ===> 현경수(3) 배우 출력됨
# ===> 임은정(3) 배우 출력됨
# ===> 이주영(3) 배우 출력됨
# ===> 이장원(3) 배우 출력됨
# ===> 김옥경(3) 배우 출력됨
# ===> 왕지혜(3) 배우 출력됨
# ===> 박명훈(3) 배우 출력됨
# ---> 50 페이지 출력됨
# ===> 김기두(3) 배우 출력됨
# ===> 오민석(3) 배우 출력됨
# ===> 김선혜(3) 배우 출력됨
# ===> 신동미(3) 배우 출력됨
# ===> 윤용식(3) 배우 출력됨
# ===> 홍승효(3) 배우 출력됨
# ===> 강승현(3) 배우 출력됨
# ---> 51 페이지 출력됨
# ===> 임성재(3) 배우 출력됨
# ===> 박수연(3) 배우 출력됨
# ===> 김현숙(3) 배우 출력됨
# ===> 김현심(3) 배우 출력됨
# ===> 김준현(3) 배우 출력됨
# ===> 손상연(3) 배우 출력됨
# ===> 서지영(3) 배우 출력됨
# ---> 52 페이지 출력됨
# ===> 김한나(3) 배우 출력됨
# ===> 이상호(3) 배우 출력됨
# ===> 김수현(3) 배우 출력됨
# ===> 박준형(3) 배우 출력됨
# ===> 박성영(3) 배우 출력됨
# ===> 배정미(3) 배우 출력됨
# ===> 하지은(3) 배우 출력됨
# ---> 53 페이지 출력됨
# ===> 이세영(3) 배우 출력됨
# ===> 종호(2) 배우 출력됨
# ===> 이창민(3) 배우 출력됨
# ===> 정국(2) 배우 출력됨
# ===> 김나연(3) 배우 출력됨
# ===> 장병관(3) 배우 출력됨
# ===> 황창영(3) 배우 출력됨
# ---> 54 페이지 출력됨
# ===> 이소영(3) 배우 출력됨
# ===> 심은경(3) 배우 출력됨
# ===> 박지영(3) 배우 출력됨
# ===> 장원영(3) 배우 출력됨
# ===> 강성우(3) 배우 출력됨
# ===> 한으뜸(3) 배우 출력됨
# ===> 전태열(3) 배우 출력됨
# ---> 55 페이지 출력됨
# ===> 엄태구(3) 배우 출력됨
# ===> 박경혜(3) 배우 출력됨
# ===> 장민혁(3) 배우 출력됨
# ===> 전후석(3) 배우 출력됨
# ===> 유민상(3) 배우 출력됨
# ===> 채민지(3) 배우 출력됨
# ===> 이유리(3) 배우 출력됨
# ---> 56 페이지 출력됨
# ===> 홍범기(3) 배우 출력됨
# ===> 이주원(3) 배우 출력됨
# ===> 김호정(3) 배우 출력됨
# ===> 최정윤(3) 배우 출력됨
# ===> 김민상(3) 배우 출력됨
# ===> 박효주(3) 배우 출력됨
# ===> 신은수(3) 배우 출력됨
# ---> 57 페이지 출력됨
# ===> 김동완(3) 배우 출력됨
# ===> 안장혁(3) 배우 출력됨
# ===> 이관희(3) 배우 출력됨
# ===> 장다운(3) 배우 출력됨
# ===> 유이화(3) 배우 출력됨
# ===> 송창의(3) 배우 출력됨
# ===> 주예림(3) 배우 출력됨
# ---> 58 페이지 출력됨
# ===> 김민준(3) 배우 출력됨
# ===> 이금희(3) 배우 출력됨
# ===> 최무성(3) 배우 출력됨
# ===> 이준혁(3) 배우 출력됨
# ===> 강말금(3) 배우 출력됨
# ===> 박소이(3) 배우 출력됨
# ===> 변영희(3) 배우 출력됨
# ---> 59 페이지 출력됨
# ===> 안지호(3) 배우 출력됨
# ===> 주진모(3) 배우 출력됨
# ===> 오현경(3) 배우 출력됨
# ===> 성훈(2) 배우 출력됨
# ===> 천정명(3) 배우 출력됨
# ===> 이혜리(3) 배우 출력됨
# ===> 김사라(3) 배우 출력됨
# ---> 60 페이지 출력됨
# ===> 손숙(2) 배우 출력됨
# ===> 김서영(3) 배우 출력됨
# ===> 문소리(3) 배우 출력됨
# ===> 정형석(3) 배우 출력됨
# ===> 염혜란(3) 배우 출력됨
# ===> 김영민(3) 배우 출력됨
# ===> 김민주(3) 배우 출력됨
# ---> 61 페이지 출력됨
# ===> 이성우(3) 배우 출력됨
# ===> 정재현(3) 배우 출력됨
# ===> 송하림(3) 배우 출력됨
# ===> 전수지(3) 배우 출력됨
# ===> 조민수(3) 배우 출력됨
# ===> 오나미(3) 배우 출력됨
# ===> 이봉근(3) 배우 출력됨
# ---> 62 페이지 출력됨
# ===> 조진숙(3) 배우 출력됨
# ===> 진이한(3) 배우 출력됨
# ===> 허가윤(3) 배우 출력됨
# ===> 최덕희(3) 배우 출력됨
# ===> 임형준(3) 배우 출력됨
# ===> 이유영(3) 배우 출력됨
# ===> 오은주(3) 배우 출력됨
# ---> 63 페이지 출력됨
# ===> 정무성(3) 배우 출력됨
# ===> 권은비(3) 배우 출력됨
# ===> 최정인(3) 배우 출력됨
# ===> 오인성(3) 배우 출력됨
# ===> 강혜원(3) 배우 출력됨
# ===> 윤찬영(3) 배우 출력됨
# ===> 류아벨(3) 배우 출력됨
# ---> 64 페이지 출력됨
# ===> 설혜인(3) 배우 출력됨
# ===> 김다올(3) 배우 출력됨
# ===> 홍기준(3) 배우 출력됨
# ===> 김학선(3) 배우 출력됨
# ===> 송영규(3) 배우 출력됨
# ===> 이하율(3) 배우 출력됨
# ===> 노강민(3) 배우 출력됨
# ---> 65 페이지 출력됨
# ===> 이다슬(3) 배우 출력됨
# ===> 박용우(3) 배우 출력됨
# ===> 최예나(3) 배우 출력됨
# ===> 구성환(3) 배우 출력됨
# ===> 한만중(3) 배우 출력됨
# ===> 문동환(3) 배우 출력됨
# ===> 홍수아(3) 배우 출력됨
# ---> 66 페이지 출력됨
# ===> 김서연(3) 배우 출력됨
# ===> 정두홍(3) 배우 출력됨
# ===> 한철우(3) 배우 출력됨
# ===> 임성철(3) 배우 출력됨
# ===> 김병춘(3) 배우 출력됨
# ===> 치타(2) 배우 출력됨
# ===> 이채연(3) 배우 출력됨
# ---> 67 페이지 출력됨
# ===> 오지혜(3) 배우 출력됨
# ===> 이열음(3) 배우 출력됨
# ===> 한송희(3) 배우 출력됨
# ===> 최재환(3) 배우 출력됨
# ===> 안영미(3) 배우 출력됨
# ===> 김보윤(3) 배우 출력됨
# ===> 김채원(3) 배우 출력됨
# ---> 68 페이지 출력됨
# ===> 김소은(3) 배우 출력됨
# ===> 곽희성(3) 배우 출력됨
# ===> 지창욱(3) 배우 출력됨
# ===> 김홍표(3) 배우 출력됨
# ===> 최다니엘(4) 배우 출력됨
# ===> 곽진석(3) 배우 출력됨
# ===> 류덕환(3) 배우 출력됨
# ---> 69 페이지 출력됨
# ===> 김창옥(3) 배우 출력됨
# ===> 고구인(3) 배우 출력됨
# ===> 김경희(3) 배우 출력됨
# ===> 오지호(3) 배우 출력됨
# ===> 최정현(3) 배우 출력됨
# ===> 조은지(3) 배우 출력됨
# ===> 정은경(3) 배우 출력됨
# ---> 70 페이지 출력됨
# ===> 민형식(3) 배우 출력됨
# ===> 최원형(3) 배우 출력됨
# ===> 박지현(3) 배우 출력됨
# ===> 최정윤(3) 배우 출력됨
# ===> 곽동연(3) 배우 출력됨
# ===> 윤승아(3) 배우 출력됨
# ===> 김소현(3) 배우 출력됨
# ---> 71 페이지 출력됨
# ===> 문성근(3) 배우 출력됨
# ===> 안효민(3) 배우 출력됨
# ===> 김대중(3) 배우 출력됨
# ===> 문영동(3) 배우 출력됨
# ===> 배상우(3) 배우 출력됨
# ===> 차엽(2) 배우 출력됨
# ===> 김꽃비(3) 배우 출력됨
# ---> 72 페이지 출력됨
# ===> 김진영(3) 배우 출력됨
# ===> 이소연(3) 배우 출력됨
# ===> 조유리(3) 배우 출력됨
# ===> 김유림(3) 배우 출력됨
# ===> 최희서(3) 배우 출력됨
# ===> 정재광(3) 배우 출력됨
# ===> 김아송(3) 배우 출력됨
# ---> 73 페이지 출력됨
# ===> 유지태(3) 배우 출력됨
# ===> 박리나(3) 배우 출력됨
# ===> 문창길(3) 배우 출력됨
# ===> 최은희(3) 배우 출력됨
# ===> 김하연(3) 배우 출력됨
# ===> 황정민(3) 배우 출력됨
# ===> 김지희(3) 배우 출력됨
# ---> 74 페이지 출력됨
# ===> 현봉식(3) 배우 출력됨
# ===> 김연우(3) 배우 출력됨
# ===> 김려원(3) 배우 출력됨
# ===> 유승호(3) 배우 출력됨
# ===> 이시아(3) 배우 출력됨
# ===> 임수정(3) 배우 출력됨
# ===> 안유진(3) 배우 출력됨
# ---> 75 페이지 출력됨
# ===> 이명호(3) 배우 출력됨
# ===> 차지혁(3) 배우 출력됨
# ===> 김성연(3) 배우 출력됨
# ===> 서은아(3) 배우 출력됨
# ===> 이시우(3) 배우 출력됨
# ===> 정의한(3) 배우 출력됨
# ===> 김새해(3) 배우 출력됨
# ---> 76 페이지 출력됨
# ===> 손선영(3) 배우 출력됨
# ===> 이운숙(3) 배우 출력됨
# ===> 오희준(3) 배우 출력됨
# ===> 홍지석(3) 배우 출력됨
# ===> 이린하(3) 배우 출력됨
# ===> 유희제(3) 배우 출력됨
# ===> 안지혜(3) 배우 출력됨
# ---> 77 페이지 출력됨
# ===> 조선기(3) 배우 출력됨
# ===> 홍수정(3) 배우 출력됨
# ===> 손정아(3) 배우 출력됨
# ===> 한인수(3) 배우 출력됨
# ===> 장원영(3) 배우 출력됨
# ===> 김을분(3) 배우 출력됨
# ===> 김희진(3) 배우 출력됨
# ---> 78 페이지 출력됨
# ===> 김소민(3) 배우 출력됨
# ===> 조승우(3) 배우 출력됨
# ===> 박예영(3) 배우 출력됨
# ===> 김상경(3) 배우 출력됨
# ===> 김강현(3) 배우 출력됨
# ===> 신영균(3) 배우 출력됨
# ===> 박건주(3) 배우 출력됨
# ---> 79 페이지 출력됨
# ===> 김진규(3) 배우 출력됨
# ===> 강희(2) 배우 출력됨
# ===> 한수연(3) 배우 출력됨
# ===> 박원상(3) 배우 출력됨
# ===> 옥윤중(3) 배우 출력됨
# ===> 이정재(3) 배우 출력됨
# ===> 주해은(3) 배우 출력됨
# ---> 80 페이지 출력됨
# ===> 조연우(3) 배우 출력됨
# ===> 심용환(3) 배우 출력됨
# ===> 이엘리야(4) 배우 출력됨
# ===> 김정훈(3) 배우 출력됨
# ===> 김소희(3) 배우 출력됨
# ===> 박누가(3) 배우 출력됨
# ===> 문선희(3) 배우 출력됨
# ---> 81 페이지 출력됨
# ===> 영민(2) 배우 출력됨
# ===> 손예진(3) 배우 출력됨
# ===> 나민희(3) 배우 출력됨
# ===> 김준범(3) 배우 출력됨
# ===> 삼숙(2) 배우 출력됨
# ===> 동효희(3) 배우 출력됨
# ===> 정다은(3) 배우 출력됨
# ---> 82 페이지 출력됨
# ===> 허지나(3) 배우 출력됨
# ===> 정제원(3) 배우 출력됨
# ===> 백재민(3) 배우 출력됨
# ===> 최낙윤(3) 배우 출력됨
# ===> 여준환(3) 배우 출력됨
# ===> 조예신(3) 배우 출력됨
# ===> 박초롱(3) 배우 출력됨
# ---> 83 페이지 출력됨
# ===> 이순도(3) 배우 출력됨
# ===> 김승호(3) 배우 출력됨
# ===> 라경덕(3) 배우 출력됨
# ===> 조인성(3) 배우 출력됨
# ===> 홍소영(3) 배우 출력됨
# ===> 박종환(3) 배우 출력됨
# ===> 윤성모(3) 배우 출력됨
# ---> 84 페이지 출력됨
# ===> 허정도(3) 배우 출력됨
# ===> 곽민규(3) 배우 출력됨
# ===> 김도훈(3) 배우 출력됨
# ===> 정의갑(3) 배우 출력됨
# ===> 장경희(3) 배우 출력됨
# ===> 민병우(3) 배우 출력됨
# ===> 신신애(3) 배우 출력됨
# ---> 85 페이지 출력됨
# ===> 조슬아(3) 배우 출력됨
# ===> 장동윤(3) 배우 출력됨
# ===> 이기우(3) 배우 출력됨
# ===> 서영화(3) 배우 출력됨
# ===> 정미숙(3) 배우 출력됨
# ===> 백서빈(3) 배우 출력됨
# ===> 도지한(3) 배우 출력됨
# ---> 86 페이지 출력됨
# ===> 김대한(3) 배우 출력됨
# ===> 김기천(3) 배우 출력됨
# ===> 이인석(3) 배우 출력됨
# ===> 안지환(3) 배우 출력됨
# ===> 장은숙(3) 배우 출력됨
# ===> 한해인(3) 배우 출력됨
# ===> 민경훈(3) 배우 출력됨
# ---> 87 페이지 출력됨
# ===> 윤혜리(3) 배우 출력됨
# ===> 오승훈(3) 배우 출력됨
# ===> 김일우(3) 배우 출력됨
# ===> 허정민(3) 배우 출력됨
# ===> 김수현(3) 배우 출력됨
# ===> 서벽준(3) 배우 출력됨
# ===> 이도하(3) 배우 출력됨
# ---> 88 페이지 출력됨
# ===> 김명국(3) 배우 출력됨
# ===> 민승연(3) 배우 출력됨
# ===> 강수진(3) 배우 출력됨
# ===> 한상혁(3) 배우 출력됨
# ===> 박선영(3) 배우 출력됨
# ===> 서나영(3) 배우 출력됨
# ===> 유승목(3) 배우 출력됨
# ---> 89 페이지 출력됨
# ===> 장리우(3) 배우 출력됨
# ===> 이주은(3) 배우 출력됨
# ===> 정예진(3) 배우 출력됨
# ===> 이솜(2) 배우 출력됨
# ===> 김하늘(3) 배우 출력됨
# ===> 김승준(3) 배우 출력됨
# ===> 홍근택(3) 배우 출력됨
# ---> 90 페이지 출력됨
# ===> 박성웅(3) 배우 출력됨
# ===> 백종학(3) 배우 출력됨
# ===> 김소형(3) 배우 출력됨
# ===> 도금봉(3) 배우 출력됨
# ===> 이지예(3) 배우 출력됨
# ===> 박혜나(3) 배우 출력됨
# ===> 남유정(3) 배우 출력됨
# ---> 91 페이지 출력됨
# ===> 전소니(3) 배우 출력됨
# ===> 추상미(3) 배우 출력됨
# ===> 이상희(3) 배우 출력됨
# ===> 김영선(3) 배우 출력됨
# ===> 이인성(3) 배우 출력됨
# ===> 이범수(3) 배우 출력됨
# ===> 김동영(3) 배우 출력됨
# ---> 92 페이지 출력됨
# ===> 이선희(3) 배우 출력됨
# ===> 곽진무(3) 배우 출력됨
# ===> 유다미(3) 배우 출력됨
# ===> 유다인(3) 배우 출력됨
# ===> 정상윤(3) 배우 출력됨
# ===> 이비안(3) 배우 출력됨
# ===> 태인호(3) 배우 출력됨
# ---> 93 페이지 출력됨
# ===> 김조연(3) 배우 출력됨
# ===> 김다예(3) 배우 출력됨
# ===> 김상원(3) 배우 출력됨
# ===> 김민주(3) 배우 출력됨
# ===> 허예은(3) 배우 출력됨
# ===> 강구한(3) 배우 출력됨
# ===> 고서희(3) 배우 출력됨
# ---> 94 페이지 출력됨
# ===> 김주령(3) 배우 출력됨
# ===> 황유림(3) 배우 출력됨
# ===> 조현철(3) 배우 출력됨
# ===> 남궁원(3) 배우 출력됨
# ===> 곽규미(3) 배우 출력됨
# ===> 김준배(3) 배우 출력됨
# ===> 윤승욱(3) 배우 출력됨
# ---> 95 페이지 출력됨
# ===> 김현욱(3) 배우 출력됨
# ===> 심은하(3) 배우 출력됨
# ===> 임예진(3) 배우 출력됨
# ===> 이정현(3) 배우 출력됨
# ===> 김도영(3) 배우 출력됨
# ===> 이상각(3) 배우 출력됨
# ===> 이천희(3) 배우 출력됨
# ---> 96 페이지 출력됨
# ===> 차지현(3) 배우 출력됨
# ===> 이한위(3) 배우 출력됨
# ===> 정영주(3) 배우 출력됨
# ===>
#
#
#
#
# 씨네21
#
#
#
#
#
#
#
#
#
# 서비스 이용에 불편을 드려 죄송합니다.
# 일시적으로 서비스 장애가 발생하였습니다.
# 빠른 시간안에 복구하도록 하겠습니다.
#
#
#
#
#
#
# ">
#
#
#
#
# 씨네21
#
#
#
#
#
#
#
#
#
# 서비스 이용에 불편을 드려 죄송합니다.
# 일시적으로 서비스 장애가 발생하였습니다.
# 빠른 시간안에 복구하도록 하겠습니다.
#
#
#
#
#
#
# (190) 배우 출력됨
# ===> 이해준(3) 배우 출력됨
# ===> 송지인(3) 배우 출력됨
# ===> 이제훈(3) 배우 출력됨
# ---> 97 페이지 출력됨
# ===> 이동휘(3) 배우 출력됨
# ===> 박요한(3) 배우 출력됨
# ===> 김윤성(3) 배우 출력됨
# ===> 김주아(3) 배우 출력됨
# ===> 남기애(3) 배우 출력됨
# ===> 김뢰하(3) 배우 출력됨
# ===> 김희철(3) 배우 출력됨
# ---> 98 페이지 출력됨
# ===> 김정영(3) 배우 출력됨
# ===> 설영범(3) 배우 출력됨
# ===> 정주원(3) 배우 출력됨
# ===> 김승현(3) 배우 출력됨
# ===> 김수진(3) 배우 출력됨
# ===> 차지현(3) 배우 출력됨
# ===> 박상증(3) 배우 출력됨
# ---> 99 페이지 출력됨
# ===> 박재한(3) 배우 출력됨
# ===> 송준석(3) 배우 출력됨
# ===> 이승찬(3) 배우 출력됨
# ===> 정지혜(3) 배우 출력됨
# ===> 하지원(3) 배우 출력됨
# ===> 이원찬(3) 배우 출력됨
# ===> 이가섭(3) 배우 출력됨
# ---> 100 페이지 출력됨
# ===> 정영숙(3) 배우 출력됨
# ===> 윤금선아(4) 배우 출력됨
# ===> 임시완(3) 배우 출력됨
# ===> 변중희(3) 배우 출력됨
# ===> 김병옥(3) 배우 출력됨
# ===> 류현경(3) 배우 출력됨
# ===> 허장강(3) 배우 출력됨
# ---> 101 페이지 출력됨
# ===> 박노식(3) 배우 출력됨
# ===> 김아현(3) 배우 출력됨
# ===> 임화영(3) 배우 출력됨
# ===> 선우선(3) 배우 출력됨
# ===> 이명희(3) 배우 출력됨
# ===> 류승룡(3) 배우 출력됨
# ===> 김희갑(3) 배우 출력됨
# ---> 102 페이지 출력됨
# ===> 류승룡(3) 배우 출력됨
# ===> 김희갑(3) 배우 출력됨
# ===> 이상원(3) 배우 출력됨
# ===> 박선영(3) 배우 출력됨
# ===> 임희철(3) 배우 출력됨
# ===> 송재림(3) 배우 출력됨
# ===> 이봉준(3) 배우 출력됨
# ---> 103 페이지 출력됨
# ===> 도경수(3) 배우 출력됨
# ===> 김지훈(3) 배우 출력됨
# ===> 이상범(3) 배우 출력됨
# ===> 권한솔(3) 배우 출력됨
# ===> 서태화(3) 배우 출력됨
# ===> 김수정(3) 배우 출력됨
# ===> 정하진(3) 배우 출력됨
# ---> 104 페이지 출력됨
# ===> 노수산나(4) 배우 출력됨
# ===> 장준현(3) 배우 출력됨
# ===> 문희(2) 배우 출력됨
# ===> 임은경(3) 배우 출력됨
# ===> 이문식(3) 배우 출력됨
# ===> 이새아(3) 배우 출력됨
# ===> 지성원(3) 배우 출력됨
# ---> 105 페이지 출력됨
# ===> 고아성(3) 배우 출력됨
# ===> 박노식(3) 배우 출력됨
# ===> 남연우(3) 배우 출력됨
# ===> 이건우(3) 배우 출력됨
# ===> 김금순(3) 배우 출력됨
# ===> 천이슬(3) 배우 출력됨
# ===> 진선미(3) 배우 출력됨
# ---> 106 페이지 출력됨
# ===> 한동규(3) 배우 출력됨
# ===> 김민주(3) 배우 출력됨
# ===> 문보람(3) 배우 출력됨
# ===> 나애진(3) 배우 출력됨
# ===> 한은진(3) 배우 출력됨
# ===> 김성규(3) 배우 출력됨
# ===> 이재범(3) 배우 출력됨
# ---> 107 페이지 출력됨
# ===> 서지희(3) 배우 출력됨
# ===> 강민준(3) 배우 출력됨
# ===> 김혜나(3) 배우 출력됨
# ===> 장선(2) 배우 출력됨
# ===> 정지순(3) 배우 출력됨
# ===> 오정세(3) 배우 출력됨
# ===> 백승헌(3) 배우 출력됨
# ---> 108 페이지 출력됨
# ===> 양현태(3) 배우 출력됨
# ===> 최무룡(3) 배우 출력됨
# ===> 전석호(3) 배우 출력됨
# ===> 최일화(3) 배우 출력됨
# ===> 기주봉(3) 배우 출력됨
# ===> 홍완표(3) 배우 출력됨
# ===> 이새봄(3) 배우 출력됨
# ---> 109 페이지 출력됨
# ===> 김동균(3) 배우 출력됨
# ===> 윤지혜(3) 배우 출력됨
# ===> 양동남(3) 배우 출력됨
# ===> 최우제(3) 배우 출력됨
# ===> 배해선(3) 배우 출력됨
# ===> 남지우(3) 배우 출력됨
# ===> 김태훈(3) 배우 출력됨
# ---> 110 페이지 출력됨
# ===> 홍승이(3) 배우 출력됨
# ===> 김규리(3) 배우 출력됨
# ===> 현빈(2) 배우 출력됨
# ===> 신린아(3) 배우 출력됨
# ===> 이설구(3) 배우 출력됨
# ===> 김현(2) 배우 출력됨
# ===> 김나니(3) 배우 출력됨
# ---> 111 페이지 출력됨
# ===> 김순규(3) 배우 출력됨
# ===> 신철진(3) 배우 출력됨
# ===> 임권택(3) 배우 출력됨
# ===> 이창성(3) 배우 출력됨
# ===> 송재호(3) 배우 출력됨
# ===> 박자희(3) 배우 출력됨
# ===> 정다원(3) 배우 출력됨
# ---> 112 페이지 출력됨
# ===> 오창석(3) 배우 출력됨
# ===> 하주희(3) 배우 출력됨
# ===> 형영선(3) 배우 출력됨
# ===> 권소현(3) 배우 출력됨
# ===> 권태원(3) 배우 출력됨
# ===> 이용한(3) 배우 출력됨
# ===> 김라희(3) 배우 출력됨
# ---> 113 페이지 출력됨
# ===> 김라희(3) 배우 출력됨
# ===> 박지아(3) 배우 출력됨
# ===> 이효제(3) 배우 출력됨
# ===> 이나라(3) 배우 출력됨
# ===> 서정연(3) 배우 출력됨
# ===> 엄앵란(3) 배우 출력됨
# ===> 양윤희(3) 배우 출력됨
# ---> 114 페이지 출력됨
# ===> 이선(2) 배우 출력됨
# ===> 최홍일(3) 배우 출력됨
# ===> 김대건(3) 배우 출력됨
# ===> 윤정욱(3) 배우 출력됨
# ===> 유상재(3) 배우 출력됨
# ===> 조영진(3) 배우 출력됨
# ===> 김태희(3) 배우 출력됨
# ---> 115 페이지 출력됨
# ===> 김현목(3) 배우 출력됨
# ===> 강두(2) 배우 출력됨
# ===> 백윤식(3) 배우 출력됨
# ===> 이대엽(3) 배우 출력됨
# ===> 이진이(3) 배우 출력됨
# ===> 남정임(3) 배우 출력됨
# ===> 류의도(3) 배우 출력됨
# ---> 116 페이지 출력됨
# ===> 윤진서(3) 배우 출력됨
# ===> 탁우석(3) 배우 출력됨
# ===> 차종수(3) 배우 출력됨
# ===> 이대근(3) 배우 출력됨
# ===> 류경수(3) 배우 출력됨
# ===> 김막동(3) 배우 출력됨
# ===> 이미자(3) 배우 출력됨
# ---> 117 페이지 출력됨
# ===> 이옥선(3) 배우 출력됨
# ===> 오창경(3) 배우 출력됨
# ===> 김다희(3) 배우 출력됨
# ===> 남석훈(3) 배우 출력됨
# ===> 서우(2) 배우 출력됨
# ===> 김의성(3) 배우 출력됨
# ===> 유순웅(3) 배우 출력됨
# ---> 118 페이지 출력됨
# ===> 김무늬(3) 배우 출력됨
# ===> 위하준(3) 배우 출력됨
# ===> 이미형(3) 배우 출력됨
# ===> 류태호(3) 배우 출력됨
# ===> 박용수(3) 배우 출력됨
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     170             conn = connection.create_connection(
# --> 171                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     172
#
# C:\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      78     if err is not None:
# ---> 79         raise err
#      80
#
# C:\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      68                 sock.bind(source_address)
# ---> 69             sock.connect(sa)
#      70             return sock
#
# TimeoutError: [WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# C:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#
# C:\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# C:\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# C:\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# C:\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# C:\Anaconda3\lib\http\client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# C:\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     195     def connect(self):
# --> 196         conn = self._new_conn()
#     197         self._prepare_conn(conn)
#
# C:\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     179             raise NewConnectionError(
# --> 180                 self, "Failed to establish a new connection: %s" % e)
#     181
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x0000011F3916AC18>: Failed to establish a new connection: [WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     444                     retries=self.max_retries,
# --> 445                     timeout=timeout
#     446                 )
#
# C:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# C:\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPConnectionPool(host='www.cine21.com', port=80): Max retries exceeded with url: /db/person/info/?person_id=3747 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000011F3916AC18>: Failed to establish a new connection: [WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-106-90fb85c8f9a7> in <module>
#      70     #print(actor_detail_full_url)
#      71
# ---> 72         res = requests.get(actor_detail_full_url)
#      73         soup = BeautifulSoup(res.text, 'html.parser')
#      74
#
# C:\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# C:\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# C:\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     510         }
#     511         send_kwargs.update(settings)
# --> 512         resp = self.send(prep, **send_kwargs)
#     513
#     514         return resp
#
# C:\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     620
#     621         # Send the request
# --> 622         r = adapter.send(request, **kwargs)
#     623
#     624         # Total elapsed time of the request (approximately)
#
# C:\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     511                 raise SSLError(e, request=request)
#     512
# --> 513             raise ConnectionError(e, request=request)
#     514
#     515         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='www.cine21.com', port=80): Max retries exceeded with url: /db/person/info/?person_id=3747 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000011F3916AC18>: Failed to establish a new connection: [WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다'))

# %%
print(len(actor_item_list))
# list comprehension >> 이상한 값들 거르기
actor_final_list = [actor for actor in actor_item_list if len(actor['배우이름']) < 10]
print(len(actor_final_list))
# Out:
# 823
# 822

# %%
import json

with open('data/')
